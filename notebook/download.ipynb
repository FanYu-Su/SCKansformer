# %%
import torch
torch.hub.set_dir('/home/suxin/SCKansformer-main/model_pth')

# %%
import torchvision.models as models

# model = models.vgg19(weights=models.VGG19_Weights.IMAGENET1K_V1)
# model = models.efficientnet_v2_m(
#     weights=models.EfficientNet_V2_M_Weights.IMAGENET1K_V1
# )
# model = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)

model = models.resnet50(
    weights=models.ResNet50_Weights.IMAGENET1K_V1
)
model = models.resnet101(
    weights=models.ResNet101_Weights.IMAGENET1K_V1
)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /home/suxin/SCKansformer-main/model_pth/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:18<00:00, 5.69MB/s]
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /home/suxin/SCKansformer-main/model_pth/checkpoints/resnet101-63fe2227.pth
# 100%|██████████| 171M/171M [01:08<00:00, 2.60MB/s]
